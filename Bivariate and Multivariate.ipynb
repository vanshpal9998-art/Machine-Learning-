# %% [markdown]
# # ***Bivariate and Multivariate***

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 1. scatterplot (Numerical - Numerical)
#
# --- Show how two numerical variables move together.

# %%
sns.scatterplot(x='Age', y='Fare', data=df, hue='Sex',style='SibSp')
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %% [markdown]
# 2.Bar Plot (Numerical - Categorical)
#
# -- To compare a numerical value across diffrent categories.

# %%
sns.barplot(x='Pclass', y='Age', data=df, hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# 3.Box plot(Numerical - Categorical)
#
# --Is used to understand the distribution of a numerical column across different categories.

# %%
sns.boxplot(x='Sex', y='Age', data=df, hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# 4. Displot (Numerical - Categorical)
#
# -- Is used to visualize the distribution of numerical data, and it can also compare distributions across categories.

# %%
sns.displot(x='Age', hue='Survived', data=df, kde=True)
sns.displot(x='Age', hue='Survived', data=df, kde=False)

# %% [markdown]
# 5. HeadMap (Categorical - Categorical)
#
# --Is a visualization that uses colors to represent values inside a matrix or table.

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
pd.crosstab(df['Pclass'], df['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(df['Pclass'], df['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
(df.groupby(['Sex','Survived'])['PassengerId'].size()*100)
# Out:
# Sex     Survived
# female  0            8100
#         1           23300
# male    0           46800
#         1           10900
# Name: PassengerId, dtype: int64

# %% [markdown]
# 6. ClusterMap (Categorical - Categorical)
#
# -- Is an advanced heatmap that not only shows values using colors but also automatically group similar rows and columns using clustring.

# %%
sns.clustermap(pd.crosstab(df['Pclass'], df['Survived']))

# %% [markdown]
# 7. Pairplot
#
# --Is used to analyze relationship between multiple numerical features together.

# %%
sns.pairplot(df, hue='Sex')

# %% [markdown]
# 8.LinePlot (NUmerical - Numerical)
#
# -- is used to how numerical values change over time or across an ordered sequence.

# %%
sns.lineplot(x='Age', y='Fare', hue='Survived', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>
